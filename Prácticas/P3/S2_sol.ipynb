# %% [markdown]
# ## Objetivos formativos
#
# - Resolver un problema de clasificación de Spam
# - Proponer diferentes métodos de combinación de árboles: bootstrap y random forests

# %% [markdown]
# # Ensembles de árboles en un dataset de detección de spam
#
# Si bien en anteriores prácticas hemos insistido en emplear entre otros el dataset de digits, es bien conocido que para este tipo de datasets que representan imágenes, no es lo habitual emplear árboles de decisión.
#
# Árboles de decisión y todos los ensembles propuestos funcionan en la práctica muy bien en datos tabulares como puede ser el problema de reconocimiento de spam en mails.
#
# Se propone pues emplear el dataset id=44 de openml de detección de Spam. Son un total de 4601 muestras con 57 características.

# %% [markdown]
# ## Un primer clasificador con un único árbol de decisión

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier

## Descarga del dataset Spam
X, y = fetch_openml(data_id=44, as_frame=False, cache=True, return_X_y=True)
print(X.shape)

## Partición train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=23)


## Grid Search
G = {"max_depth": [2,4,6,8,10], "min_samples_split": [2,3,4]}

GS = GridSearchCV(DecisionTreeClassifier(random_state=23), G, scoring='accuracy', refit=True, cv=5)

acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
# Out:
# (4601, 57)
# Precisión: 93.9% con {'max_depth': 10, 'min_samples_split': 4}

# %% [markdown]
# ## Bagging
#
# Bagging es una técnica genérica de muestreo con remplanzamiento del conjunto de muestras de entrenamiento. Se puede emplear junto con cualquier clasificador para obtener un ensemble. Los parámetros más importantes son por un lado el estimador que se quiere emplear, en nuestro caso un DecisionTree, y el número de estimadores que se quiere combinar en el ensemble.

# %%
from sklearn.ensemble import BaggingClassifier

clf= BaggingClassifier(estimator=DecisionTreeClassifier(random_state=23,max_depth=10,min_samples_split=4),n_estimators=100)

acc = clf.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%}')
# Out:
# Precisión: 94.9%

# %% [markdown]
# **Ejercicio:** Encuentra los mejores parámetros mediante grid search. En concreto, n_estimators y max_depth de los árboles de decisión empleados. Se debería poder llegar alrededor de un **94.5% de acierto**.

# %%
### SOLUCION
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

DT = DecisionTreeClassifier(random_state=23)
bagging_clf = BaggingClassifier(estimator=DT, random_state=42)

G = {
    'estimator__max_depth': [18, 20],  # del DT
    'estimator__min_samples_split': [2, 3], # del DT
    'n_estimators': [50], # del Bagging
    #'max_samples': [0.8, 1.0],  # del Bagging
    #'max_features': [0.8, 1.0], # del Bagging
}

# Configurar GridSearchCV
grid_search = GridSearchCV(bagging_clf, G, scoring='accuracy', cv=5,  refit=True, verbose=10)

# Ajustar el GridSearchCV
grid_search.fit(X_train, y_train)

# Imprimir los mejores parámetros y la precisión en el conjunto de prueba
print(f"Mejores parámetros: {grid_search.best_params_}")
best_clf = grid_search.best_estimator_

# Evaluar en el conjunto de prueba
y_pred = best_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Precisión en el conjunto de prueba: {accuracy:.1%}')
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5; 1/4] START estimator__max_depth=18, estimator__min_samples_split=2, n_estimators=50
# [CV 1/5; 1/4] END estimator__max_depth=18, estimator__min_samples_split=2, n_estimators=50;, score=0.938 total time=   1.0s
# [CV 2/5; 1/4] START estimator__max_depth=18, estimator__min_samples_split=2, n_estimators=50
# [CV 2/5; 1/4] END estimator__max_depth=18, estimator__min_samples_split=2, n_estimators=50;, score=0.931 total time=   1.1s
# [CV 3/5; 1/4] START estimator__max_depth=18, estimator__min_samples_split=2, n_estimators=50
# [CV 3/5; 1/4] END estimator__max_depth=18, estimator__min_samples_split=2, n_estimators=50;, score=0.947 total time=   1.0s
# [CV 4/5; 1/4] START estimator__max_depth=18, estimator__min_samples_split=2, n_estimators=50
# [CV 4/5; 1/4] END estimator__max_depth=18, estimator__min_samples_split=2, n_estimators=50;, score=0.933 total time=   1.0s
# [CV 5/5; 1/4] START estimator__max_depth=18, estimator__min_samples_split=2, n_estimators=50
# [CV 5/5; 1/4] END estimator__max_depth=18, estimator__min_samples_split=2, n_estimators=50;, score=0.943 total time=   1.0s
# [CV 1/5; 2/4] START estimator__max_depth=18, estimator__min_samples_split=3, n_estimators=50
# [CV 1/5; 2/4] END estimator__max_depth=18, estimator__min_samples_split=3, n_estimators=50;, score=0.938 total time=   1.0s
# [CV 2/5; 2/4] START estimator__max_depth=18, estimator__min_samples_split=3, n_estimators=50
# [CV 2/5; 2/4] END estimator__max_depth=18, estimator__min_samples_split=3, n_estimators=50;, score=0.932 total time=   1.1s
# [CV 3/5; 2/4] START estimator__max_depth=18, estimator__min_samples_split=3, n_estimators=50
# [CV 3/5; 2/4] END estimator__max_depth=18, estimator__min_samples_split=3, n_estimators=50;, score=0.948 total time=   1.0s
# [CV 4/5; 2/4] START estimator__max_depth=18, estimator__min_samples_split=3, n_estimators=50
# [CV 4/5; 2/4] END estimator__max_depth=18, estimator__min_samples_split=3, n_estimators=50;, score=0.942 total time=   1.0s
# [CV 5/5; 2/4] START estimator__max_depth=18, estimator__min_samples_split=3, n_estimators=50
# [CV 5/5; 2/4] END estimator__max_depth=18, estimator__min_samples_split=3, n_estimators=50;, score=0.946 total time=   1.0s
# [CV 1/5; 3/4] START estimator__max_depth=20, estimator__min_samples_split=2, n_estimators=50
# [CV 1/5; 3/4] END estimator__max_depth=20, estimator__min_samples_split=2, n_estimators=50;, score=0.939 total time=   1.1s
# [CV 2/5; 3/4] START estimator__max_depth=20, estimator__min_samples_split=2, n_estimators=50
# [CV 2/5; 3/4] END estimator__max_depth=20, estimator__min_samples_split=2, n_estimators=50;, score=0.933 total time=   1.1s
# [CV 3/5; 3/4] START estimator__max_depth=20, estimator__min_samples_split=2, n_estimators=50
# [CV 3/5; 3/4] END estimator__max_depth=20, estimator__min_samples_split=2, n_estimators=50;, score=0.948 total time=   1.1s
# [CV 4/5; 3/4] START estimator__max_depth=20, estimator__min_samples_split=2, n_estimators=50
# [CV 4/5; 3/4] END estimator__max_depth=20, estimator__min_samples_split=2, n_estimators=50;, score=0.938 total time=   1.0s
# [CV 5/5; 3/4] START estimator__max_depth=20, estimator__min_samples_split=2, n_estimators=50
# [CV 5/5; 3/4] END estimator__max_depth=20, estimator__min_samples_split=2, n_estimators=50;, score=0.943 total time=   1.0s
# [CV 1/5; 4/4] START estimator__max_depth=20, estimator__min_samples_split=3, n_estimators=50
# [CV 1/5; 4/4] END estimator__max_depth=20, estimator__min_samples_split=3, n_estimators=50;, score=0.936 total time=   1.1s
# [CV 2/5; 4/4] START estimator__max_depth=20, estimator__min_samples_split=3, n_estimators=50
# [CV 2/5; 4/4] END estimator__max_depth=20, estimator__min_samples_split=3, n_estimators=50;, score=0.933 total time=   1.1s
# [CV 3/5; 4/4] START estimator__max_depth=20, estimator__min_samples_split=3, n_estimators=50
# [CV 3/5; 4/4] END estimator__max_depth=20, estimator__min_samples_split=3, n_estimators=50;, score=0.948 total time=   1.1s
# [CV 4/5; 4/4] START estimator__max_depth=20, estimator__min_samples_split=3, n_estimators=50
# [CV 4/5; 4/4] END estimator__max_depth=20, estimator__min_samples_split=3, n_estimators=50;, score=0.940 total time=   1.0s
# [CV 5/5; 4/4] START estimator__max_depth=20, estimator__min_samples_split=3, n_estimators=50
# [CV 5/5; 4/4] END estimator__max_depth=20, estimator__min_samples_split=3, n_estimators=50;, score=0.946 total time=   1.0s
# Mejores parámetros: {'estimator__max_depth': 18, 'estimator__min_samples_split': 3, 'n_estimators': 50}
# Precisión en el conjunto de prueba: 94.8%

# %% [markdown]
# ## RandomForest
#
# RandomForest es otra técnica de ensemble, en este caso no genérica sino particular para árboles de decisión. Cada árbol se construye empleando una selección aleatoria de las características en cada uno de los nodos. El parámetro más importante es "n_estimators", el número de árboles que se combinan. El parámetro binario "bootstrap" controla también si se realiza bootstrap de las muestras (Bagging) o no.

# %%
from sklearn.ensemble import RandomForestClassifier

clf= RandomForestClassifier(n_estimators=10, max_depth=10, min_samples_split=4, bootstrap=False, random_state=23)

acc = clf.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%}')
# Out:
# Precisión: 94.1%

# %% [markdown]
# **Ejercicio:** Realiza una búsqueda de parámetros mediande grid search. En concreto para los parámetros: n_estimators, max_depth y bootstrap. Se debería poder llegar alrededor de un **95% de acierto**.

# %%
# Solucion
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# Define el modelo base
RF = RandomForestClassifier(random_state=23)

# Define el espacio de búsqueda de hiperparámetros
G = {
    'n_estimators': [10, 50, 100, 200],  # Número de árboles
    'max_depth': [5, 10, 20, None],  # Profundidad máxima del árbol
    #'min_samples_split': [2, 4, 8],  # Muestras mínimas para dividir un nodo
    'max_features': ['sqrt', 'log2', 0.5],  # Máximo número de características consideradas
    'bootstrap': [True, False],  # Si se emplea muestreo con reemplazo
    #'criterion': ['gini', 'entropy'],  # Criterio para medir la calidad de una división
}

# Configurar GridSearchCV
grid_search = GridSearchCV(RF, G, scoring='accuracy', cv=5, refit=True, verbose=10)

# Ajustar el GridSearchCV
grid_search.fit(X_train, y_train)

# Imprimir los mejores parámetros y la precisión en el conjunto de prueba
print(f"Mejores parámetros: {grid_search.best_params_}")
best_rf_clf = grid_search.best_estimator_

# Evaluar en el conjunto de prueba
y_pred = best_rf_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Precisión en el conjunto de prueba: {accuracy:.1%}')
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV 1/5; 1/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=10
# [CV 1/5; 1/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=10;, score=0.913 total time=   0.0s
# [CV 2/5; 1/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=10
# [CV 2/5; 1/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=10;, score=0.912 total time=   0.0s
# [CV 3/5; 1/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=10
# [CV 3/5; 1/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=10;, score=0.931 total time=   0.0s
# [CV 4/5; 1/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=10
# [CV 4/5; 1/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=10;, score=0.925 total time=   0.0s
# [CV 5/5; 1/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=10
# [CV 5/5; 1/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=10;, score=0.917 total time=   0.0s
# [CV 1/5; 2/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=50
# [CV 1/5; 2/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=50;, score=0.931 total time=   0.1s
# [CV 2/5; 2/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=50
# [CV 2/5; 2/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=50;, score=0.917 total time=   0.1s
# [CV 3/5; 2/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=50
# [CV 3/5; 2/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=50;, score=0.935 total time=   0.1s
# [CV 4/5; 2/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=50
# [CV 4/5; 2/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=50;, score=0.912 total time=   0.1s
# [CV 5/5; 2/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=50
# [CV 5/5; 2/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=50;, score=0.924 total time=   0.1s
# [CV 1/5; 3/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=100
# [CV 1/5; 3/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.932 total time=   0.2s
# [CV 2/5; 3/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=100
# [CV 2/5; 3/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.920 total time=   0.2s
# [CV 3/5; 3/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=100
# [CV 3/5; 3/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.929 total time=   0.2s
# [CV 4/5; 3/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=100
# [CV 4/5; 3/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.917 total time=   0.2s
# [CV 5/5; 3/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=100
# [CV 5/5; 3/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.921 total time=   0.2s
# [CV 1/5; 4/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=200
# [CV 1/5; 4/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.933 total time=   0.3s
# [CV 2/5; 4/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=200
# [CV 2/5; 4/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.913 total time=   0.3s
# [CV 3/5; 4/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=200
# [CV 3/5; 4/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.933 total time=   0.3s
# [CV 4/5; 4/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=200
# [CV 4/5; 4/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.916 total time=   0.3s
# [CV 5/5; 4/96] START bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=200
# [CV 5/5; 4/96] END bootstrap=True, max_depth=5, max_features=sqrt, n_estimators=200;, score=0.918 total time=   0.3s
# [CV 1/5; 5/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=10
# [CV 1/5; 5/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=10;, score=0.914 total time=   0.0s
# [CV 2/5; 5/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=10
# [CV 2/5; 5/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=10;, score=0.901 total time=   0.0s
# [CV 3/5; 5/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=10
# [CV 3/5; 5/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=10;, score=0.923 total time=   0.0s
# [CV 4/5; 5/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=10
# [CV 4/5; 5/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=10;, score=0.904 total time=   0.0s
# [CV 5/5; 5/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=10
# [CV 5/5; 5/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=10;, score=0.916 total time=   0.0s
# [CV 1/5; 6/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=50
# [CV 1/5; 6/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=50;, score=0.924 total time=   0.1s
# [CV 2/5; 6/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=50
# [CV 2/5; 6/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=50;, score=0.914 total time=   0.1s
# [CV 3/5; 6/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=50
# [CV 3/5; 6/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=50;, score=0.928 total time=   0.1s
# [CV 4/5; 6/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=50
# [CV 4/5; 6/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=50;, score=0.912 total time=   0.1s
# [CV 5/5; 6/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=50
# [CV 5/5; 6/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=50;, score=0.920 total time=   0.1s
# [CV 1/5; 7/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=100
# [CV 1/5; 7/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=100;, score=0.925 total time=   0.1s
# [CV 2/5; 7/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=100
# [CV 2/5; 7/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=100;, score=0.917 total time=   0.1s
# [CV 3/5; 7/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=100
# [CV 3/5; 7/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=100;, score=0.924 total time=   0.1s
# [CV 4/5; 7/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=100
# [CV 4/5; 7/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=100;, score=0.913 total time=   0.1s
# [CV 5/5; 7/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=100
# [CV 5/5; 7/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=100;, score=0.920 total time=   0.1s
# [CV 1/5; 8/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=200
# [CV 1/5; 8/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=200;, score=0.924 total time=   0.3s
# [CV 2/5; 8/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=200
# [CV 2/5; 8/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=200;, score=0.913 total time=   0.3s
# [CV 3/5; 8/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=200
# [CV 3/5; 8/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=200;, score=0.932 total time=   0.3s
# [CV 4/5; 8/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=200
# [CV 4/5; 8/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=200;, score=0.914 total time=   0.3s
# [CV 5/5; 8/96] START bootstrap=True, max_depth=5, max_features=log2, n_estimators=200
# [CV 5/5; 8/96] END bootstrap=True, max_depth=5, max_features=log2, n_estimators=200;, score=0.917 total time=   0.3s
# [CV 1/5; 9/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=10
# [CV 1/5; 9/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=10;, score=0.924 total time=   0.0s
# [CV 2/5; 9/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=10
# [CV 2/5; 9/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=10;, score=0.910 total time=   0.0s
# [CV 3/5; 9/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=10
# [CV 3/5; 9/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=10;, score=0.929 total time=   0.0s
# [CV 4/5; 9/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=10
# [CV 4/5; 9/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=10;, score=0.914 total time=   0.0s
# [CV 5/5; 9/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=10
# [CV 5/5; 9/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=10;, score=0.923 total time=   0.0s
# [CV 1/5; 10/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=50
# [CV 1/5; 10/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=50;, score=0.927 total time=   0.2s
# [CV 2/5; 10/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=50
# [CV 2/5; 10/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=50;, score=0.913 total time=   0.2s
# [CV 3/5; 10/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=50
# [CV 3/5; 10/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=50;, score=0.928 total time=   0.2s
# [CV 4/5; 10/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=50
# [CV 4/5; 10/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=50;, score=0.921 total time=   0.2s
# [CV 5/5; 10/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=50
# [CV 5/5; 10/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=50;, score=0.928 total time=   0.2s
# [CV 1/5; 11/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=100
# [CV 1/5; 11/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=100;, score=0.927 total time=   0.4s
# [CV 2/5; 11/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=100
# [CV 2/5; 11/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=100;, score=0.912 total time=   0.4s
# [CV 3/5; 11/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=100
# [CV 3/5; 11/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=100;, score=0.928 total time=   0.4s
# [CV 4/5; 11/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=100
# [CV 4/5; 11/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=100;, score=0.923 total time=   0.4s
# [CV 5/5; 11/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=100
# [CV 5/5; 11/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=100;, score=0.928 total time=   0.4s
# [CV 1/5; 12/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=200
# [CV 1/5; 12/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=200;, score=0.921 total time=   0.9s
# [CV 2/5; 12/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=200
# [CV 2/5; 12/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=200;, score=0.914 total time=   0.9s
# [CV 3/5; 12/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=200
# [CV 3/5; 12/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=200;, score=0.927 total time=   0.9s
# [CV 4/5; 12/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=200
# [CV 4/5; 12/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=200;, score=0.923 total time=   0.9s
# [CV 5/5; 12/96] START bootstrap=True, max_depth=5, max_features=0.5, n_estimators=200
# [CV 5/5; 12/96] END bootstrap=True, max_depth=5, max_features=0.5, n_estimators=200;, score=0.928 total time=   0.9s
# [CV 1/5; 13/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=10
# [CV 1/5; 13/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=10;, score=0.932 total time=   0.0s
# [CV 2/5; 13/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=10
# [CV 2/5; 13/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=10;, score=0.925 total time=   0.0s
# [CV 3/5; 13/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=10
# [CV 3/5; 13/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=10;, score=0.939 total time=   0.0s
# [CV 4/5; 13/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=10
# [CV 4/5; 13/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=10;, score=0.929 total time=   0.0s
# [CV 5/5; 13/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=10
# [CV 5/5; 13/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=10;, score=0.936 total time=   0.0s
# [CV 1/5; 14/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=50
# [CV 1/5; 14/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=50;, score=0.947 total time=   0.1s
# [CV 2/5; 14/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=50
# [CV 2/5; 14/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=50;, score=0.939 total time=   0.1s
# [CV 3/5; 14/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=50
# [CV 3/5; 14/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=50;, score=0.948 total time=   0.1s
# [CV 4/5; 14/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=50
# [CV 4/5; 14/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=50;, score=0.936 total time=   0.1s
# [CV 5/5; 14/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=50
# [CV 5/5; 14/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=50;, score=0.932 total time=   0.1s
# [CV 1/5; 15/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100
# [CV 1/5; 15/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.947 total time=   0.2s
# [CV 2/5; 15/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100
# [CV 2/5; 15/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.939 total time=   0.2s
# [CV 3/5; 15/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100
# [CV 3/5; 15/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.946 total time=   0.2s
# [CV 4/5; 15/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100
# [CV 4/5; 15/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.933 total time=   0.2s
# [CV 5/5; 15/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100
# [CV 5/5; 15/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100;, score=0.938 total time=   0.2s
# [CV 1/5; 16/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 16/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.942 total time=   0.5s
# [CV 2/5; 16/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 16/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.938 total time=   0.4s
# [CV 3/5; 16/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 16/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.943 total time=   0.5s
# [CV 4/5; 16/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 16/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.931 total time=   0.4s
# [CV 5/5; 16/96] START bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 16/96] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.938 total time=   0.4s
# [CV 1/5; 17/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=10
# [CV 1/5; 17/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=10;, score=0.936 total time=   0.0s
# [CV 2/5; 17/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=10
# [CV 2/5; 17/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=10;, score=0.920 total time=   0.0s
# [CV 3/5; 17/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=10
# [CV 3/5; 17/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=10;, score=0.944 total time=   0.0s
# [CV 4/5; 17/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=10
# [CV 4/5; 17/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=10;, score=0.933 total time=   0.0s
# [CV 5/5; 17/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=10
# [CV 5/5; 17/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=10;, score=0.943 total time=   0.0s
# [CV 1/5; 18/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=50
# [CV 1/5; 18/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=50;, score=0.935 total time=   0.1s
# [CV 2/5; 18/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=50
# [CV 2/5; 18/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=50;, score=0.936 total time=   0.1s
# [CV 3/5; 18/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=50
# [CV 3/5; 18/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=50;, score=0.951 total time=   0.1s
# [CV 4/5; 18/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=50
# [CV 4/5; 18/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=50;, score=0.931 total time=   0.1s
# [CV 5/5; 18/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=50
# [CV 5/5; 18/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=50;, score=0.935 total time=   0.1s
# [CV 1/5; 19/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=100
# [CV 1/5; 19/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=100;, score=0.939 total time=   0.2s
# [CV 2/5; 19/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=100
# [CV 2/5; 19/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=100;, score=0.935 total time=   0.2s
# [CV 3/5; 19/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=100
# [CV 3/5; 19/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=100;, score=0.946 total time=   0.2s
# [CV 4/5; 19/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=100
# [CV 4/5; 19/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=100;, score=0.935 total time=   0.2s
# [CV 5/5; 19/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=100
# [CV 5/5; 19/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=100;, score=0.938 total time=   0.2s
# [CV 1/5; 20/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=200
# [CV 1/5; 20/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=200;, score=0.939 total time=   0.4s
# [CV 2/5; 20/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=200
# [CV 2/5; 20/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=200;, score=0.936 total time=   0.4s
# [CV 3/5; 20/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=200
# [CV 3/5; 20/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=200;, score=0.947 total time=   0.4s
# [CV 4/5; 20/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=200
# [CV 4/5; 20/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=200;, score=0.936 total time=   0.4s
# [CV 5/5; 20/96] START bootstrap=True, max_depth=10, max_features=log2, n_estimators=200
# [CV 5/5; 20/96] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=200;, score=0.932 total time=   0.4s
# [CV 1/5; 21/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=10
# [CV 1/5; 21/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=10;, score=0.933 total time=   0.1s
# [CV 2/5; 21/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=10
# [CV 2/5; 21/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=10;, score=0.938 total time=   0.1s
# [CV 3/5; 21/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=10
# [CV 3/5; 21/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=10;, score=0.946 total time=   0.1s
# [CV 4/5; 21/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=10
# [CV 4/5; 21/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=10;, score=0.925 total time=   0.1s
# [CV 5/5; 21/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=10
# [CV 5/5; 21/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=10;, score=0.936 total time=   0.1s
# [CV 1/5; 22/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=50
# [CV 1/5; 22/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=50;, score=0.936 total time=   0.4s
# [CV 2/5; 22/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=50
# [CV 2/5; 22/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=50;, score=0.936 total time=   0.4s
# [CV 3/5; 22/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=50
# [CV 3/5; 22/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=50;, score=0.936 total time=   0.4s
# [CV 4/5; 22/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=50
# [CV 4/5; 22/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=50;, score=0.932 total time=   0.4s
# [CV 5/5; 22/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=50
# [CV 5/5; 22/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=50;, score=0.942 total time=   0.4s
# [CV 1/5; 23/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=100
# [CV 1/5; 23/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=100;, score=0.936 total time=   0.7s
# [CV 2/5; 23/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=100
# [CV 2/5; 23/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=100;, score=0.931 total time=   0.7s
# [CV 3/5; 23/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=100
# [CV 3/5; 23/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=100;, score=0.938 total time=   0.7s
# [CV 4/5; 23/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=100
# [CV 4/5; 23/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=100;, score=0.935 total time=   0.7s
# [CV 5/5; 23/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=100
# [CV 5/5; 23/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=100;, score=0.942 total time=   0.7s
# [CV 1/5; 24/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=200
# [CV 1/5; 24/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=200;, score=0.936 total time=   1.5s
# [CV 2/5; 24/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=200
# [CV 2/5; 24/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=200;, score=0.931 total time=   1.4s
# [CV 3/5; 24/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=200
# [CV 3/5; 24/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=200;, score=0.938 total time=   1.5s
# [CV 4/5; 24/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=200
# [CV 4/5; 24/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=200;, score=0.936 total time=   1.4s
# [CV 5/5; 24/96] START bootstrap=True, max_depth=10, max_features=0.5, n_estimators=200
# [CV 5/5; 24/96] END bootstrap=True, max_depth=10, max_features=0.5, n_estimators=200;, score=0.940 total time=   1.4s
# [CV 1/5; 25/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=10
# [CV 1/5; 25/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=10;, score=0.938 total time=   0.0s
# [CV 2/5; 25/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=10
# [CV 2/5; 25/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=10;, score=0.933 total time=   0.0s
# [CV 3/5; 25/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=10
# [CV 3/5; 25/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=10;, score=0.958 total time=   0.0s
# [CV 4/5; 25/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=10
# [CV 4/5; 25/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=10;, score=0.931 total time=   0.0s
# [CV 5/5; 25/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=10
# [CV 5/5; 25/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=10;, score=0.950 total time=   0.0s
# [CV 1/5; 26/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=50
# [CV 1/5; 26/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=50;, score=0.948 total time=   0.1s
# [CV 2/5; 26/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=50
# [CV 2/5; 26/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=50;, score=0.951 total time=   0.1s
# [CV 3/5; 26/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=50
# [CV 3/5; 26/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=50;, score=0.963 total time=   0.1s
# [CV 4/5; 26/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=50
# [CV 4/5; 26/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=50;, score=0.943 total time=   0.1s
# [CV 5/5; 26/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=50
# [CV 5/5; 26/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=50;, score=0.955 total time=   0.1s
# [CV 1/5; 27/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=100
# [CV 1/5; 27/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.950 total time=   0.3s
# [CV 2/5; 27/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=100
# [CV 2/5; 27/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.952 total time=   0.3s
# [CV 3/5; 27/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=100
# [CV 3/5; 27/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.962 total time=   0.3s
# [CV 4/5; 27/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=100
# [CV 4/5; 27/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.947 total time=   0.3s
# [CV 5/5; 27/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=100
# [CV 5/5; 27/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.954 total time=   0.3s
# [CV 1/5; 28/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 28/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.944 total time=   0.5s
# [CV 2/5; 28/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 28/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.952 total time=   0.5s
# [CV 3/5; 28/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 28/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.961 total time=   0.5s
# [CV 4/5; 28/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 28/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.946 total time=   0.5s
# [CV 5/5; 28/96] START bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 28/96] END bootstrap=True, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.951 total time=   0.5s
# [CV 1/5; 29/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=10
# [CV 1/5; 29/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=10;, score=0.932 total time=   0.0s
# [CV 2/5; 29/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=10
# [CV 2/5; 29/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=10;, score=0.929 total time=   0.0s
# [CV 3/5; 29/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=10
# [CV 3/5; 29/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=10;, score=0.950 total time=   0.0s
# [CV 4/5; 29/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=10
# [CV 4/5; 29/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=10;, score=0.940 total time=   0.0s
# [CV 5/5; 29/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=10
# [CV 5/5; 29/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=10;, score=0.936 total time=   0.0s
# [CV 1/5; 30/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=50
# [CV 1/5; 30/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=50;, score=0.948 total time=   0.1s
# [CV 2/5; 30/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=50
# [CV 2/5; 30/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=50;, score=0.946 total time=   0.1s
# [CV 3/5; 30/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=50
# [CV 3/5; 30/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=50;, score=0.961 total time=   0.1s
# [CV 4/5; 30/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=50
# [CV 4/5; 30/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=50;, score=0.951 total time=   0.1s
# [CV 5/5; 30/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=50
# [CV 5/5; 30/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=50;, score=0.951 total time=   0.1s
# [CV 1/5; 31/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=100
# [CV 1/5; 31/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=100;, score=0.948 total time=   0.2s
# [CV 2/5; 31/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=100
# [CV 2/5; 31/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=100;, score=0.948 total time=   0.2s
# [CV 3/5; 31/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=100
# [CV 3/5; 31/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=100;, score=0.963 total time=   0.2s
# [CV 4/5; 31/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=100
# [CV 4/5; 31/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=100;, score=0.946 total time=   0.2s
# [CV 5/5; 31/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=100
# [CV 5/5; 31/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/5; 32/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=200
# [CV 1/5; 32/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=200;, score=0.946 total time=   0.4s
# [CV 2/5; 32/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=200
# [CV 2/5; 32/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=200;, score=0.954 total time=   0.4s
# [CV 3/5; 32/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=200
# [CV 3/5; 32/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=200;, score=0.961 total time=   0.4s
# [CV 4/5; 32/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=200
# [CV 4/5; 32/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=200;, score=0.944 total time=   0.4s
# [CV 5/5; 32/96] START bootstrap=True, max_depth=20, max_features=log2, n_estimators=200
# [CV 5/5; 32/96] END bootstrap=True, max_depth=20, max_features=log2, n_estimators=200;, score=0.954 total time=   0.4s
# [CV 1/5; 33/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=10
# [CV 1/5; 33/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=10;, score=0.936 total time=   0.1s
# [CV 2/5; 33/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=10
# [CV 2/5; 33/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=10;, score=0.927 total time=   0.1s
# [CV 3/5; 33/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=10
# [CV 3/5; 33/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=10;, score=0.948 total time=   0.1s
# [CV 4/5; 33/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=10
# [CV 4/5; 33/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=10;, score=0.933 total time=   0.1s
# [CV 5/5; 33/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=10
# [CV 5/5; 33/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=10;, score=0.944 total time=   0.1s
# [CV 1/5; 34/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=50
# [CV 1/5; 34/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=50;, score=0.943 total time=   0.5s
# [CV 2/5; 34/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=50
# [CV 2/5; 34/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=50;, score=0.943 total time=   0.5s
# [CV 3/5; 34/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=50
# [CV 3/5; 34/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=50;, score=0.954 total time=   0.5s
# [CV 4/5; 34/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=50
# [CV 4/5; 34/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=50;, score=0.935 total time=   0.5s
# [CV 5/5; 34/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=50
# [CV 5/5; 34/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=50;, score=0.948 total time=   0.5s
# [CV 1/5; 35/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=100
# [CV 1/5; 35/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=100;, score=0.940 total time=   1.0s
# [CV 2/5; 35/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=100
# [CV 2/5; 35/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=100;, score=0.946 total time=   0.9s
# [CV 3/5; 35/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=100
# [CV 3/5; 35/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=100;, score=0.952 total time=   1.0s
# [CV 4/5; 35/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=100
# [CV 4/5; 35/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=100;, score=0.936 total time=   0.9s
# [CV 5/5; 35/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=100
# [CV 5/5; 35/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=100;, score=0.952 total time=   0.9s
# [CV 1/5; 36/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=200
# [CV 1/5; 36/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=200;, score=0.944 total time=   1.9s
# [CV 2/5; 36/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=200
# [CV 2/5; 36/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=200;, score=0.942 total time=   1.9s
# [CV 3/5; 36/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=200
# [CV 3/5; 36/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=200;, score=0.954 total time=   2.0s
# [CV 4/5; 36/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=200
# [CV 4/5; 36/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=200;, score=0.938 total time=   1.9s
# [CV 5/5; 36/96] START bootstrap=True, max_depth=20, max_features=0.5, n_estimators=200
# [CV 5/5; 36/96] END bootstrap=True, max_depth=20, max_features=0.5, n_estimators=200;, score=0.950 total time=   1.8s
# [CV 1/5; 37/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=10
# [CV 1/5; 37/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=10;, score=0.940 total time=   0.0s
# [CV 2/5; 37/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=10
# [CV 2/5; 37/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=10;, score=0.927 total time=   0.0s
# [CV 3/5; 37/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=10
# [CV 3/5; 37/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=10;, score=0.961 total time=   0.0s
# [CV 4/5; 37/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=10
# [CV 4/5; 37/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=10;, score=0.939 total time=   0.0s
# [CV 5/5; 37/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=10
# [CV 5/5; 37/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=10;, score=0.946 total time=   0.0s
# [CV 1/5; 38/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=50
# [CV 1/5; 38/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.947 total time=   0.1s
# [CV 2/5; 38/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=50
# [CV 2/5; 38/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.950 total time=   0.1s
# [CV 3/5; 38/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=50
# [CV 3/5; 38/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.959 total time=   0.1s
# [CV 4/5; 38/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=50
# [CV 4/5; 38/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.947 total time=   0.1s
# [CV 5/5; 38/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=50
# [CV 5/5; 38/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.961 total time=   0.1s
# [CV 1/5; 39/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=100
# [CV 1/5; 39/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.942 total time=   0.3s
# [CV 2/5; 39/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=100
# [CV 2/5; 39/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 3/5; 39/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=100
# [CV 3/5; 39/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.959 total time=   0.3s
# [CV 4/5; 39/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=100
# [CV 4/5; 39/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.950 total time=   0.3s
# [CV 5/5; 39/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=100
# [CV 5/5; 39/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.952 total time=   0.3s
# [CV 1/5; 40/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=200
# [CV 1/5; 40/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.943 total time=   0.6s
# [CV 2/5; 40/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=200
# [CV 2/5; 40/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.952 total time=   0.5s
# [CV 3/5; 40/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=200
# [CV 3/5; 40/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.966 total time=   0.5s
# [CV 4/5; 40/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=200
# [CV 4/5; 40/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.946 total time=   0.5s
# [CV 5/5; 40/96] START bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=200
# [CV 5/5; 40/96] END bootstrap=True, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.955 total time=   0.5s
# [CV 1/5; 41/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=10
# [CV 1/5; 41/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=10;, score=0.948 total time=   0.0s
# [CV 2/5; 41/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=10
# [CV 2/5; 41/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=10;, score=0.935 total time=   0.0s
# [CV 3/5; 41/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=10
# [CV 3/5; 41/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=10;, score=0.958 total time=   0.0s
# [CV 4/5; 41/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=10
# [CV 4/5; 41/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=10;, score=0.947 total time=   0.0s
# [CV 5/5; 41/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=10
# [CV 5/5; 41/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=10;, score=0.940 total time=   0.0s
# [CV 1/5; 42/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=50
# [CV 1/5; 42/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=50;, score=0.948 total time=   0.1s
# [CV 2/5; 42/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=50
# [CV 2/5; 42/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=50;, score=0.948 total time=   0.1s
# [CV 3/5; 42/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=50
# [CV 3/5; 42/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=50;, score=0.965 total time=   0.1s
# [CV 4/5; 42/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=50
# [CV 4/5; 42/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=50;, score=0.944 total time=   0.1s
# [CV 5/5; 42/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=50
# [CV 5/5; 42/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=50;, score=0.957 total time=   0.1s
# [CV 1/5; 43/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=100
# [CV 1/5; 43/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 2/5; 43/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=100
# [CV 2/5; 43/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=100;, score=0.952 total time=   0.2s
# [CV 3/5; 43/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=100
# [CV 3/5; 43/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=100;, score=0.963 total time=   0.2s
# [CV 4/5; 43/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=100
# [CV 4/5; 43/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=100;, score=0.942 total time=   0.2s
# [CV 5/5; 43/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=100
# [CV 5/5; 43/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=100;, score=0.958 total time=   0.2s
# [CV 1/5; 44/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=200
# [CV 1/5; 44/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 2/5; 44/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=200
# [CV 2/5; 44/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=200;, score=0.954 total time=   0.4s
# [CV 3/5; 44/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=200
# [CV 3/5; 44/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 4/5; 44/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=200
# [CV 4/5; 44/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=200;, score=0.946 total time=   0.4s
# [CV 5/5; 44/96] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=200
# [CV 5/5; 44/96] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=200;, score=0.959 total time=   0.4s
# [CV 1/5; 45/96] START bootstrap=True, max_depth=None, max_features=0.5, n_estimators=10
# [CV 1/5; 45/96] END bootstrap=True, max_depth=None, max_features=0.5, n_estimators=10;, score=0.936 total time=   0.1s
# [CV 2/5; 45/96] START bootstrap=True, max_depth=None, max_features=0.5, n_estimators=10
# [CV 2/5; 45/96] END bootstrap=True, max_depth=None, max_features=0.5, n_estimators=10;, score=0.942 total time=   0.1s
# [CV 3/5; 45/96] START bootstrap=True, max_depth=None, max_features=0.5, n_estimators=10
# [CV 3/5; 45/96] END bootstrap=True, max_depth=None, max_features=0.5, n_estimators=10;, score=0.942 total time=   0.1s
# [CV 4/5; 45/96] START bootstrap=True, max_depth=None, max_features=0.5, n_estimators=10
# [CV 4/5; 45/96] END bootstrap=True, max_depth=None, max_features=0.5, n_estimators=10;, score=0.925 total time=   0.1s
# [CV 5/5; 45/96] START bootstrap=True, max_depth=None, max_features=0.5, n_estimators=10
# [CV 5/5; 45/96] END bootstrap=True, max_depth=None, max_features=0.5, n_estimators=10;, score=0.939 total time=   0.1s
# [CV 1/5; 46/96] START bootstrap=True, max_depth=None, max_features=0.5, n_estimators=50
# [CV 1/5; 46/96] END bootstrap=True, max_depth=None, max_features=0.5, n_estimators=50;, score=0.939 total time=   0.5s
# [CV 2/5; 46/96] START bootstrap=True, max_depth=None, max_features=0.5, n_estimators=50
# [CV 2/5; 46/96] END bootstrap=True, max_depth=None, max_features=0.5, n_estimators=50;, score=0.944 total time=   0.5s
# [CV 3/5; 46/96] START bootstrap=True, max_depth=None, max_features=0.5, n_estimators=50
# [CV 3/5; 46/96] END bootstrap=True, max_depth=None, max_features=0.5, n_estimators=50;, score=0.951 total time=   0.5s
# [CV 4/5; 46/96] START bootstrap=True, max_depth=None, max_features=0.5, n_estimators=50
# [CV 4/5; 46/96] END bootstrap=True, max_depth=None, max_features=0.5, n_estimators=50;, score=0.939 total time=   0.5s
# [CV 5/5; 46/96] START bootstrap=True, max_depth=None, max_features=0.5, n_estimators=50
# [CV 5/5; 46/96] END bootstrap=True, max_depth=None, max_features=0.5, n_estimators=50;, score=0.946 total time=   0.5s
# [CV 1/5; 47/96] START bootstrap=True, max_depth=None, max_features=0.5, n_estimators=100
# [CV 1/5; 47/96] END bootstrap=True, max_depth=None, max_features=0.5, n_estimators=100;, score=0.936 total time=   1.0s
# [CV 2/5; 47/96] START bootstrap=True, max_depth=None, max_features=0.5, n_estimators=100
# [CV 2/5; 47/96] END bootstrap=True, max_depth=None, max_features=0.5, n_estimators=100;, score=0.947 total time=   1.0s
# [CV 3/5; 47/96] START bootstrap=True, max_depth=None, max_features=0.5, n_estimators=100
# [CV 3/5; 47/96] END bootstrap=True, max_depth=None, max_features=0.5, n_estimators=100;, score=0.957 total time=   1.0s
# [CV 4/5; 47/96] START bootstrap=True, max_depth=None, max_features=0.5, n_estimators=100
# ...
# [CV 1/5; 82/96] START bootstrap=False, max_depth=20, max_features=0.5, n_estimators=50
# [CV 1/5; 82/96] END bootstrap=False, max_depth=20, max_features=0.5, n_estimators=50;, score=0.939 total time=   0.7s
# [CV 2/5; 82/96] START bootstrap=False, max_depth=20, max_features=0.5, n_estimators=50
# [CV 2/5; 82/96] END bootstrap=False, max_depth=20, max_features=0.5, n_estimators=50;, score=0.942 total time=   0.7s
# [CV 3/5; 82/96] START bootstrap=False, max_depth=20, max_features=0.5, n_estimators=50
# [CV 3/5; 82/96] END bootstrap=False, max_depth=20, max_features=0.5, n_estimators=50;, score=0.947 total time=   0.7s
# [CV 4/5; 82/96] START bootstrap=False, max_depth=20, max_features=0.5, n_estimators=50
# [CV 4/5; 82/96] END bootstrap=False, max_depth=20, max_features=0.5, n_estimators=50;, score=0.940 total time=   0.7s
# [CV 5/5; 82/96] START bootstrap=False, max_depth=20, max_features=0.5, n_estimators=50
# [CV 5/5; 82/96] END bootstrap=False, max_depth=20, max_features=0.5, n_estimators=50;, score=0.958 total time=   0.7s
# [CV 1/5; 83/96] START bootstrap=False, max_depth=20, max_features=0.5, n_estimators=100
# [CV 1/5; 83/96] END bootstrap=False, max_depth=20, max_features=0.5, n_estimators=100;, score=0.943 total time=   1.4s
# [CV 2/5; 83/96] START bootstrap=False, max_depth=20, max_features=0.5, n_estimators=100
# [CV 2/5; 83/96] END bootstrap=False, max_depth=20, max_features=0.5, n_estimators=100;, score=0.940 total time=   1.4s
# [CV 3/5; 83/96] START bootstrap=False, max_depth=20, max_features=0.5, n_estimators=100
# [CV 3/5; 83/96] END bootstrap=False, max_depth=20, max_features=0.5, n_estimators=100;, score=0.943 total time=   1.4s
# [CV 4/5; 83/96] START bootstrap=False, max_depth=20, max_features=0.5, n_estimators=100
# [CV 4/5; 83/96] END bootstrap=False, max_depth=20, max_features=0.5, n_estimators=100;, score=0.932 total time=   1.3s
# [CV 5/5; 83/96] START bootstrap=False, max_depth=20, max_features=0.5, n_estimators=100
# [CV 5/5; 83/96] END bootstrap=False, max_depth=20, max_features=0.5, n_estimators=100;, score=0.958 total time=   1.3s
# [CV 1/5; 84/96] START bootstrap=False, max_depth=20, max_features=0.5, n_estimators=200
# [CV 1/5; 84/96] END bootstrap=False, max_depth=20, max_features=0.5, n_estimators=200;, score=0.942 total time=   2.8s
# [CV 2/5; 84/96] START bootstrap=False, max_depth=20, max_features=0.5, n_estimators=200
# [CV 2/5; 84/96] END bootstrap=False, max_depth=20, max_features=0.5, n_estimators=200;, score=0.938 total time=   2.8s
# [CV 3/5; 84/96] START bootstrap=False, max_depth=20, max_features=0.5, n_estimators=200
# [CV 3/5; 84/96] END bootstrap=False, max_depth=20, max_features=0.5, n_estimators=200;, score=0.946 total time=   2.8s
# [CV 4/5; 84/96] START bootstrap=False, max_depth=20, max_features=0.5, n_estimators=200
# [CV 4/5; 84/96] END bootstrap=False, max_depth=20, max_features=0.5, n_estimators=200;, score=0.939 total time=   2.7s
# [CV 5/5; 84/96] START bootstrap=False, max_depth=20, max_features=0.5, n_estimators=200
# [CV 5/5; 84/96] END bootstrap=False, max_depth=20, max_features=0.5, n_estimators=200;, score=0.955 total time=   2.6s
# [CV 1/5; 85/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=10
# [CV 1/5; 85/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=10;, score=0.944 total time=   0.0s
# [CV 2/5; 85/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=10
# [CV 2/5; 85/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=10;, score=0.939 total time=   0.0s
# [CV 3/5; 85/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=10
# [CV 3/5; 85/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=10;, score=0.954 total time=   0.0s
# [CV 4/5; 85/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=10
# [CV 4/5; 85/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=10;, score=0.932 total time=   0.0s
# [CV 5/5; 85/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=10
# [CV 5/5; 85/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=10;, score=0.947 total time=   0.0s
# [CV 1/5; 86/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=50
# [CV 1/5; 86/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.948 total time=   0.2s
# [CV 2/5; 86/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=50
# [CV 2/5; 86/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.952 total time=   0.2s
# [CV 3/5; 86/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=50
# [CV 3/5; 86/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.958 total time=   0.2s
# [CV 4/5; 86/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=50
# [CV 4/5; 86/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.943 total time=   0.2s
# [CV 5/5; 86/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=50
# [CV 5/5; 86/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=50;, score=0.957 total time=   0.2s
# [CV 1/5; 87/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=100
# [CV 1/5; 87/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.944 total time=   0.4s
# [CV 2/5; 87/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=100
# [CV 2/5; 87/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.954 total time=   0.4s
# [CV 3/5; 87/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=100
# [CV 3/5; 87/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.962 total time=   0.4s
# [CV 4/5; 87/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=100
# [CV 4/5; 87/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.950 total time=   0.4s
# [CV 5/5; 87/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=100
# [CV 5/5; 87/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=100;, score=0.952 total time=   0.4s
# [CV 1/5; 88/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=200
# [CV 1/5; 88/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.950 total time=   0.7s
# [CV 2/5; 88/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=200
# [CV 2/5; 88/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.952 total time=   0.7s
# [CV 3/5; 88/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=200
# [CV 3/5; 88/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.959 total time=   0.7s
# [CV 4/5; 88/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=200
# [CV 4/5; 88/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.946 total time=   0.7s
# [CV 5/5; 88/96] START bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=200
# [CV 5/5; 88/96] END bootstrap=False, max_depth=None, max_features=sqrt, n_estimators=200;, score=0.957 total time=   0.7s
# [CV 1/5; 89/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=10
# [CV 1/5; 89/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=10;, score=0.942 total time=   0.0s
# [CV 2/5; 89/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=10
# [CV 2/5; 89/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=10;, score=0.950 total time=   0.0s
# [CV 3/5; 89/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=10
# [CV 3/5; 89/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=10;, score=0.943 total time=   0.0s
# [CV 4/5; 89/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=10
# [CV 4/5; 89/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=10;, score=0.940 total time=   0.0s
# [CV 5/5; 89/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=10
# [CV 5/5; 89/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=10;, score=0.939 total time=   0.0s
# [CV 1/5; 90/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=50
# [CV 1/5; 90/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=50;, score=0.947 total time=   0.1s
# [CV 2/5; 90/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=50
# [CV 2/5; 90/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=50;, score=0.958 total time=   0.1s
# [CV 3/5; 90/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=50
# [CV 3/5; 90/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=50;, score=0.957 total time=   0.2s
# [CV 4/5; 90/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=50
# [CV 4/5; 90/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=50;, score=0.946 total time=   0.1s
# [CV 5/5; 90/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=50
# [CV 5/5; 90/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=50;, score=0.958 total time=   0.1s
# [CV 1/5; 91/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=100
# [CV 1/5; 91/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=100;, score=0.946 total time=   0.3s
# [CV 2/5; 91/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=100
# [CV 2/5; 91/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=100;, score=0.959 total time=   0.3s
# [CV 3/5; 91/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=100
# [CV 3/5; 91/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=100;, score=0.961 total time=   0.3s
# [CV 4/5; 91/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=100
# [CV 4/5; 91/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=100;, score=0.946 total time=   0.3s
# [CV 5/5; 91/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=100
# [CV 5/5; 91/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=100;, score=0.957 total time=   0.3s
# [CV 1/5; 92/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=200
# [CV 1/5; 92/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=200;, score=0.942 total time=   0.6s
# [CV 2/5; 92/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=200
# [CV 2/5; 92/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=200;, score=0.955 total time=   0.6s
# [CV 3/5; 92/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=200
# [CV 3/5; 92/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=200;, score=0.963 total time=   0.6s
# [CV 4/5; 92/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=200
# [CV 4/5; 92/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=200;, score=0.948 total time=   0.6s
# [CV 5/5; 92/96] START bootstrap=False, max_depth=None, max_features=log2, n_estimators=200
# [CV 5/5; 92/96] END bootstrap=False, max_depth=None, max_features=log2, n_estimators=200;, score=0.961 total time=   0.6s
# [CV 1/5; 93/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=10
# [CV 1/5; 93/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=10;, score=0.939 total time=   0.2s
# [CV 2/5; 93/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=10
# [CV 2/5; 93/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=10;, score=0.936 total time=   0.1s
# [CV 3/5; 93/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=10
# [CV 3/5; 93/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=10;, score=0.944 total time=   0.1s
# [CV 4/5; 93/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=10
# [CV 4/5; 93/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=10;, score=0.932 total time=   0.1s
# [CV 5/5; 93/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=10
# [CV 5/5; 93/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=10;, score=0.957 total time=   0.1s
# [CV 1/5; 94/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=50
# [CV 1/5; 94/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=50;, score=0.939 total time=   0.7s
# [CV 2/5; 94/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=50
# [CV 2/5; 94/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=50;, score=0.942 total time=   0.7s
# [CV 3/5; 94/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=50
# [CV 3/5; 94/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=50;, score=0.943 total time=   0.7s
# [CV 4/5; 94/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=50
# [CV 4/5; 94/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=50;, score=0.940 total time=   0.7s
# [CV 5/5; 94/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=50
# [CV 5/5; 94/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=50;, score=0.955 total time=   0.7s
# [CV 1/5; 95/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=100
# [CV 1/5; 95/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=100;, score=0.942 total time=   1.4s
# [CV 2/5; 95/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=100
# [CV 2/5; 95/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=100;, score=0.940 total time=   1.4s
# [CV 3/5; 95/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=100
# [CV 3/5; 95/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=100;, score=0.946 total time=   1.4s
# [CV 4/5; 95/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=100
# [CV 4/5; 95/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=100;, score=0.943 total time=   1.4s
# [CV 5/5; 95/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=100
# [CV 5/5; 95/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=100;, score=0.959 total time=   1.3s
# [CV 1/5; 96/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=200
# [CV 1/5; 96/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=200;, score=0.942 total time=   3.0s
# [CV 2/5; 96/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=200
# [CV 2/5; 96/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=200;, score=0.942 total time=   2.8s
# [CV 3/5; 96/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=200
# [CV 3/5; 96/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=200;, score=0.948 total time=   2.8s
# [CV 4/5; 96/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=200
# [CV 4/5; 96/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=200;, score=0.942 total time=   2.7s
# [CV 5/5; 96/96] START bootstrap=False, max_depth=None, max_features=0.5, n_estimators=200
# [CV 5/5; 96/96] END bootstrap=False, max_depth=None, max_features=0.5, n_estimators=200;, score=0.959 total time=   2.6s
# Mejores parámetros: {'bootstrap': True, 'max_depth': None, 'max_features': 'log2', 'n_estimators': 200}
# Precisión en el conjunto de prueba: 95.8%

# %%
# Solucion
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# Define el modelo base
RF = RandomForestClassifier(random_state=23)

# Define el espacio de búsqueda de hiperparámetros
G = {
    'n_estimators': [200,300,400,500,750,1000],  # Número de árboles
    'max_depth': [None],  # Profundidad máxima del árbol
    #'min_samples_split': [2, 4, 8],  # Muestras mínimas para dividir un nodo
    'max_features': ['log2'],  # Máximo número de características consideradas
    'bootstrap': [True],  # Si se emplea muestreo con reemplazo
    #'criterion': ['gini', 'entropy'],  # Criterio para medir la calidad de una división
}

# Configurar GridSearchCV
grid_search = GridSearchCV(RF, G, scoring='accuracy', cv=5, refit=True, verbose=10)

# Ajustar el GridSearchCV
grid_search.fit(X_train, y_train)

# Imprimir los mejores parámetros y la precisión en el conjunto de prueba
print(f"Mejores parámetros: {grid_search.best_params_}")
best_rf_clf = grid_search.best_estimator_

# Evaluar en el conjunto de prueba
y_pred = best_rf_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Precisión en el conjunto de prueba: {accuracy:.1%}')
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5; 1/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=200
# [CV 1/5; 1/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=200;, score=0.951 total time=   0.4s
# [CV 2/5; 1/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=200
# [CV 2/5; 1/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=200;, score=0.954 total time=   0.4s
# [CV 3/5; 1/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=200
# [CV 3/5; 1/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 4/5; 1/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=200
# [CV 4/5; 1/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=200;, score=0.946 total time=   0.4s
# [CV 5/5; 1/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=200
# [CV 5/5; 1/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=200;, score=0.959 total time=   0.4s
# [CV 1/5; 2/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=300
# [CV 1/5; 2/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=300;, score=0.951 total time=   0.7s
# [CV 2/5; 2/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=300
# [CV 2/5; 2/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=300;, score=0.952 total time=   0.7s
# [CV 3/5; 2/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=300
# [CV 3/5; 2/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=300;, score=0.965 total time=   0.7s
# [CV 4/5; 2/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=300
# [CV 4/5; 2/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=300;, score=0.943 total time=   0.6s
# [CV 5/5; 2/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=300
# [CV 5/5; 2/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=300;, score=0.958 total time=   0.6s
# [CV 1/5; 3/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=400
# [CV 1/5; 3/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=400;, score=0.951 total time=   0.9s
# [CV 2/5; 3/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=400
# [CV 2/5; 3/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=400;, score=0.952 total time=   0.9s
# [CV 3/5; 3/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=400
# [CV 3/5; 3/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=400;, score=0.963 total time=   0.9s
# [CV 4/5; 3/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=400
# [CV 4/5; 3/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=400;, score=0.943 total time=   0.9s
# [CV 5/5; 3/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=400
# [CV 5/5; 3/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=400;, score=0.959 total time=   0.9s
# [CV 1/5; 4/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=500
# [CV 1/5; 4/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=500;, score=0.951 total time=   1.1s
# [CV 2/5; 4/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=500
# [CV 2/5; 4/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=500;, score=0.955 total time=   1.1s
# [CV 3/5; 4/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=500
# [CV 3/5; 4/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=500;, score=0.966 total time=   1.1s
# [CV 4/5; 4/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=500
# [CV 4/5; 4/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=500;, score=0.944 total time=   1.1s
# [CV 5/5; 4/4] START bootstrap=True, max_depth=None, max_features=log2, n_estimators=500
# [CV 5/5; 4/4] END bootstrap=True, max_depth=None, max_features=log2, n_estimators=500;, score=0.957 total time=   1.1s
# Mejores parámetros: {'bootstrap': True, 'max_depth': None, 'max_features': 'log2', 'n_estimators': 500}
# Precisión en el conjunto de prueba: 95.9%
